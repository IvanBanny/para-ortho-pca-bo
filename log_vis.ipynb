# %%
import os
import pandas as pd

pd.set_option("display.width", 1000)

problem = 19
instance = 1

log_dir = f"logs/log_{problem}_{instance}"

# %%
os.listdir(log_dir)
# Out:
# ['10.csv',
#  '11.csv',
#  '12.csv',
#  '13.csv',
#  '14.csv',
#  '15.csv',
#  '16.csv',
#  '17.csv',
#  '18.csv',
#  '19.csv',
#  '20.csv',
#  '6.csv',
#  '7.csv',
#  '8.csv',
#  '9.csv']

# %%
evals = 20

pd.read_csv(os.path.join(log_dir, f"{evals}.csv"))
# Out:
#                             x              z           p          acqf   penalty         pacqf
# 0                   [ 0. -4.]  [-1.86746672]  -88.910574  3.599685e-10  0.000000  3.599685e-10
# 1                   [-2.  4.]   [2.61312159]  -31.552652  3.580957e-10  0.000000  3.580957e-10
# 2                     [4. 2.]   [5.24759343]  -93.147771  3.688179e-10  0.000000  3.688179e-10
# 3                   [-4. -2.]  [-3.13662259]  -63.524460  3.650803e-10  0.000000  3.650803e-10
# 4                     [2. 0.]   [2.42080139] -101.991355  3.577045e-10  0.000000  3.577045e-10
# 5     [4.63612147 2.59404375]   [6.11593719]  -88.446526  3.743782e-10  0.000000  3.743782e-10
# 6     [4.0482135  2.91975473]   [5.95260652]  -79.171406  3.732677e-10  0.000000  3.732677e-10
# 7     [4.86509056 4.36163147]   [7.56388835]  -74.624100  3.860786e-10 -1.064768 -1.064768e+00
# 8     [4.88099605 4.99839923]   [8.04005678]  -87.071835  3.905780e-10 -4.315372 -4.315372e+00
# ...

# %%
for f in os.listdir(log_dir):
    df = pd.read_csv(os.path.join(log_dir, f))
    print(f"\n{f.split('.')[0]} evals:\n{df}\n\n")
# Out:
# 10 evals:
#                            x              z           p          acqf   penalty         pacqf
# 0                  [ 0. -4.]   [-5.8488729]  -88.910574  3.503905e-07  0.000000  3.503905e-07
# 1                  [-2.  4.]  [-0.23153847]  -31.552652  3.439725e-07  0.000000  3.439725e-07
# 2                    [4. 2.]    [1.3617455]  -93.147771  3.445761e-07  0.000000  3.445761e-07
# 3                  [-4. -2.]  [-6.35211411]  -63.524460  3.516235e-07  0.000000  3.516235e-07
# 4                    [2. 0.]  [-1.40514155] -101.991355  3.441885e-07  0.000000  3.441885e-07
# 5    [4.63612147 2.59404375]   [2.20650473]  -88.446526  3.453461e-07  0.000000  3.453461e-07
# 6    [4.0482135  2.91975473]   [2.15916563]  -79.171406  3.452796e-07  0.000000  3.452796e-07
# 7    [4.86509056 4.36163147]   [3.81328248]  -74.624100  3.476449e-07  0.000000  3.476449e-07
# 8    [4.88099605 4.99839923]   [4.35583151]  -87.071835  3.486665e-07 -1.521716 -1.521716e+00
# ...
